# %%
from api_functions import *

# %%
stock =input()
stock = stock.upper()
print(stock)
# Out:
# Goog
# GOOG

# %% [markdown]
# # You will display back the user: Name Ticker, Full Name of the Stock, Current Price, Target Mean Price, Cash on Hand, Profit Margins

# %%
try:
    data = yf.Ticker(stock)
    jdict = display_info(stock)
    write_json(jdict, stock)
    plot_5_days(stock)

except Exception:
    print("Not a valid name")
# Out:
# Name Ticker: GOOG
# Full Name of Stock: Alphabet Inc.
# Current Name: 97.18
# Target Mean Price: 148.95
# Cash on Hand: 124997001216
# Profit Margins: 0.25892
# Time Pulled: 2022-10-16 22:31:48.816061
#
# Date
# 2022-10-11 00:00:00-04:00    98.050003
# 2022-10-12 00:00:00-04:00    98.300003
# 2022-10-13 00:00:00-04:00    99.709999
# 2022-10-14 00:00:00-04:00    97.180000
# Name: Close, dtype: float64
# Five days ago was: 2022-10-11 00:00:00
